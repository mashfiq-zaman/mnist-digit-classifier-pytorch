# %%
import torch
import torch.nn as nn

w=torch.tensor(0.0, requires_grad=True)

class MyModel(nn.Module):
  def __init__(self):

      super().__init__()

self.w=nn.parameter(torch.tensor(0.0))
# Out:
# d:\1pytorch\venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:362: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class mymodel(nn.Module):
     def __init__(self):
          
          super().__init__()
          self.linear=nn.Linear(1,1)
     def forward(self,x):
          return self.linear(x)
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])

model = mymodel()

loss_fn=nn.MSELoss()
opti= optim.Adam(model.parameters(), lr=0.1)

for i in range(10):
     opti.zero_grad()
     y_pred=model(x)
     loss=loss_fn(y_pred, y)
     loss.backward()
     opti.step()
     print(f"epoch {i+1}, loss : {loss.item():.4f}")


torch.save(model.state_dict(), "linear_model.pth")
# Out:
# epoch 1, loss : 43.8822
# epoch 2, loss : 39.1633
# epoch 3, loss : 34.7226
# epoch 4, loss : 30.5644
# epoch 5, loss : 26.6919
# epoch 6, loss : 23.1072
# epoch 7, loss : 19.8110
# epoch 8, loss : 16.8027
# epoch 9, loss : 14.0799
# epoch 10, loss : 11.6387
